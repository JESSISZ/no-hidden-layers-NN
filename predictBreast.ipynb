# %%
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
X = data.data
Y = data.target

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

data = load_breast_cancer()

X = data.data        
Y = data.target      


X_train, X_test, y_train, y_test = train_test_split(
    X, Y, random_state=42, train_size=0.8
)

X_train = X_train.T
X_test = X_test.T

y_train = y_train.reshape(1, -1)
y_test = y_test.reshape(1, -1)

X_train = (X_train - X_train.mean(axis=1, keepdims=True)) / X_train.std(axis=1, keepdims=True)
X_test = (X_test - X_test.mean(axis=1, keepdims=True)) / X_test.std(axis=1, keepdims=True)

print(X_train.shape)
print(y_train.shape)
# Out:
# (30, 455)
# (1, 455)

# %%
from nohiddenPT import oneLayerNN
model = oneLayerNN()
model.fit(X_train,y_train)
# Out:
# Avg cost in the iter 0 is: 0.693
# Avg cost in the iter 100 is: 0.279
# Avg cost in the iter 200 is: 0.210
# Avg cost in the iter 300 is: 0.178
# Avg cost in the iter 400 is: 0.159
# Avg cost in the iter 500 is: 0.146
# Avg cost in the iter 600 is: 0.137
# Avg cost in the iter 700 is: 0.130
# Avg cost in the iter 800 is: 0.124
# Avg cost in the iter 900 is: 0.119

# %%
y_pred = model.predict(X_test)

count = 0
for i in range(len(y_pred[0])):
    if y_pred[0][i] == y_test[0][i]:
        count += 1
    
print(f"Accuracy of the model: {count/len(y_pred[0]) * 100 :.2f}%")
# Out:
# Accuracy of the model: 98.25%
